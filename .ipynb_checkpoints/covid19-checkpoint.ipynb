# %%
import pandas as pd
import numpy as np
import string
import matplotlib.pyplot as plt

# %%
# Download latest Covid 19 data
df = pd.read_csv("https://covid.ourworldindata.org/data/ecdc/full_data.csv")
# Downloaded population from World Bank
# http://api.worldbank.org/v2/en/indicator/SP.POP.TOTL?downloadformat=csv
pop = pd.read_csv("population.csv", skiprows=4)
pop = pop.set_index('Country Name')

# %%
# Default values
values_def = 'new_cases'
since_def = '2020-03-01'
countries_def=['Italy','Spain','United Kingdom','Ireland','China','United States','Iran']

# Set the default size for the figures
plt.rcParams["figure.figsize"] = (14, 10)

# %%
# @global df - data frame containing Covid 19 data by date and by country
# @global pop - data frome containing population data
# @param values - one of 'new cases', 'total cases', 'new deaths', total deaths'
# @param since - show data only for dates since this date; format 'yyyy-mm-dd'
# @param countries - show data only for the specified countries
# @param by_pop - set to 1 to divide numbers by population per country, in millions
def covid(values=values_def, since=since_def, countries=countries_def, by_pop=0):
    # filter by date
    df2 = df[df.date >= since]
    # generate a pivot chart
    piv = df2.pivot(index='date', columns='location', values=values)
    # filter by country
    if (countries == []):
        sub = piv.drop(columns='World')
    else:
        sub = piv[countries]
    # setup title of plot
    title=values + " since " + since
    if (by_pop == 1):
        # divide each number by the population, in millions
        pop2 = pop.loc[countries, ['2018']]
        pop2 = pop2/1e6
        pop2 = pop2.transpose()
        sub = sub/pop2.iloc[0]
        title = title + " per million of population"
    # define lines for doubling every N days
    return sub, title

# %%
# use all defaults from above
sub, title = covid()
sub.plot(title=title,logy=False)

# %%
sub, title = covid(by_pop=1)
sub.plot(title=title,logy=False)

# %%
sub, title = covid(values='new_deaths',countries=['World'],since='2020-01-01')
sub.plot(title=title,logy=True)

# %%
sub, title=covid(countries=[])
lastrow=sub.shape[0]-1
lastrow_name=sub.index[lastrow]
sub.sort_values(by=lastrow_name,axis=1,ascending=False,inplace=True)
sub.iloc[lastrow,:10]
# Out:
# location
# United States     18695.0
# Spain              7871.0
# Germany            6294.0
# Italy              5959.0
# France             3809.0
# Iran               2926.0
# United Kingdom     2885.0
# Turkey             2069.0
# Switzerland        1390.0
# Netherlands        1172.0
# Name: 2020-03-28, dtype: float64

# %%
sub, title=covid(countries=[],by_pop=1)
last_row=sub.shape[0]-1
last_row_name=sub.index[last_row]
sub.sort_values(by=last_row_name,axis=1,ascending=False,inplace=True)
sub.iloc[last_row,:10]
# Out:
# location
# Afghanistan           NaN
# Albania               NaN
# Algeria               NaN
# Andorra               NaN
# Angola                NaN
# Anguilla              NaN
# Antigua and Barbuda   NaN
# Argentina             NaN
# Armenia               NaN
# Aruba                 NaN
# Name: 2020-03-28, dtype: float64

# %%
pop.loc[['Aruba'],['2018']]
# Out:
#                   2018
# Country Name
# Aruba         105845.0

# %%
sub
# Out:
# 2020-03-03                               NaN          NaN       NaN   NaN
# 2020-03-04                               NaN          NaN       NaN   NaN
# 2020-03-05                               NaN          NaN       NaN   NaN
# 2020-03-06                               NaN          NaN       NaN   NaN
# 2020-03-07                               NaN          NaN       NaN   NaN
# 2020-03-08                               NaN          NaN       NaN   NaN
# 2020-03-09                               NaN          NaN       NaN   NaN
# 2020-03-10                               NaN          NaN       NaN   NaN
# 2020-03-11                               NaN          NaN       NaN   NaN
# 2020-03-12                               NaN          NaN       NaN   NaN
# 2020-03-13                               1.0          NaN       NaN   NaN
# 2020-03-14                               NaN          NaN       NaN   NaN
# 2020-03-15                               NaN          NaN       NaN   NaN
# 2020-03-16                               NaN          NaN       NaN   NaN
# 2020-03-17                               NaN          NaN       NaN   NaN
# 2020-03-18                               NaN          NaN       NaN   NaN
# 2020-03-19                               NaN          1.0       NaN   NaN
# 2020-03-20                               NaN          0.0       NaN   NaN
# 2020-03-21                               NaN          2.0       NaN   NaN
# 2020-03-22                               NaN          0.0       NaN   NaN
# 2020-03-23                               NaN          0.0       1.0   NaN
# 2020-03-24                               NaN          2.0       0.0   NaN
# 2020-03-25                               0.0          4.0       1.0   NaN
# 2020-03-26                               0.0          4.0       5.0   2.0
# 2020-03-27                               0.0          0.0       4.0   2.0
# 2020-03-28                               0.0          0.0       0.0   0.0
#
# location    Kenya  International
# date
# 2020-03-01    NaN            0.0
# 2020-03-02    NaN            0.0
# 2020-03-03    NaN            NaN
# 2020-03-04    NaN            NaN
# 2020-03-05    NaN            NaN
# 2020-03-06    NaN            NaN
# 2020-03-07    NaN            NaN
# 2020-03-08    NaN            NaN
# 2020-03-09    NaN            NaN
# 2020-03-10    NaN           -9.0
# 2020-03-11    NaN            NaN
# 2020-03-12    NaN            NaN
# 2020-03-13    NaN            NaN
# 2020-03-14    1.0            NaN
# 2020-03-15    0.0            NaN
# 2020-03-16    2.0            NaN
# 2020-03-17    0.0            NaN
# 2020-03-18    1.0            NaN
# 2020-03-19    3.0            NaN
# 2020-03-20    0.0            NaN
# 2020-03-21    0.0            NaN
# 2020-03-22    0.0            NaN
# 2020-03-23    8.0            NaN
# 2020-03-24    1.0            NaN
# 2020-03-25    9.0            NaN
# 2020-03-26    0.0            NaN
# 2020-03-27    6.0            NaN
# 2020-03-28    0.0            NaN
#
# [28 rows x 196 columns]

# %%
sub.index
# Out:
# Index(['2020-03-01', '2020-03-02', '2020-03-03', '2020-03-04', '2020-03-05',
#        '2020-03-06', '2020-03-07', '2020-03-08', '2020-03-09', '2020-03-10',
#        '2020-03-11', '2020-03-12', '2020-03-13', '2020-03-14', '2020-03-15',
#        '2020-03-16', '2020-03-17', '2020-03-18', '2020-03-19', '2020-03-20',
#        '2020-03-21', '2020-03-22', '2020-03-23', '2020-03-24', '2020-03-25',
#        '2020-03-26', '2020-03-27', '2020-03-28'],
#       dtype='object', name='date')

# %%
pop.index
# Out:
# Index(['Aruba', 'Afghanistan', 'Angola', 'Albania', 'Andorra', 'Arab World',
#        'United Arab Emirates', 'Argentina', 'Armenia', 'American Samoa',
#        ...
#        'Virgin Islands (U.S.)', 'Vietnam', 'Vanuatu', 'World', 'Samoa',
#        'Kosovo', 'Yemen, Rep.', 'South Africa', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country Name', length=264)
